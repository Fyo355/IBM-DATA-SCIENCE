# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Fabrizio Oyarzabal</b>
#
# Data Scientist / Artificial intelligence

# %% [markdown]
# <em>Hola! I'm interesed in Data Science because I want to work with AI</em>

# %% [markdown]
# <h3>The below should print "Hola Messi" 3 TIMES</h3>

# %%
A = 1;
while(A < 4):
    print("Hola Messi")
    A = A + 1
# Out:
# Hola Messi
# Hola Messi
# Hola Messi

# %% [markdown]
# *  Bulleted List 1
#
# *  Bulleted List 2
#
# *  Bulleted List 3
#
#
#
# 1. Numbered List 1
#
# 2. Numbered List 2
#
# 3. Numbered List 3
#
#
# > Blockquotes
